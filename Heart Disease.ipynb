# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
df = pd.read_csv(r'D:\python class arja mohan\data stes\Heart Disease//heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  calo  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  \
# 0   45    1   3   200    1        0      150      0      2.3      0   0     1
# 1   37    1   2   300    0        1      187      0      3.5      0   0     2
# 2   41    0   1   150    0        0      172      0      1.4      2   0     2
# 3   40    1   1   120    0        1      178      0      0.8      2   0     2
# 4   55    0   0   260    0        1      163      1      0.6      2   0     2
#
#    target
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1

# %%
x =df[['age','oldpeak']]
y =df['target']

# %%
x.head()
# Out:
#    age  oldpeak
# 0   63      2.3
# 1   37      3.5
# 2   41      1.4
# 3   56      0.8
# 4   57      0.6

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: target, dtype: int64

# %%
decision = DecisionTreeClassifier(random_state = 0)
fit = decision.fit(x,y)

# %%
plt.figure(figsize=(10,10))
tree.plot_tree(fit,filled = True)
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63    1   3       145    1        0      150      0      2.3      0   0
# 1   37    1   2       130    0        1      187      0      3.5      0   0
# 2   41    0   1       130    0        0      172      0      1.4      2   0
# 3   56    1   1       120    0        1      178      0      0.8      2   0
# 4   57    0   0       120    0        1      163      1      0.6      2   0
#
#    thal  target
# 0     1       0
# 1     2       1
# 2     2       0
# 3     2       0
# 4     2       1

# %%
print(tree.export_text(fit))
# Out:
# |--- feature_1 <= 1.35
# |   |--- feature_0 <= 50.50
# |   |   |--- class: 1
# |   |--- feature_0 >  50.50
# |   |   |--- feature_0 <= 55.00
# |   |   |   |--- class: 0
# |   |   |--- feature_0 >  55.00
# |   |   |   |--- feature_0 <= 57.50
# |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |--- feature_1 <= 0.70
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  0.70
# |   |   |   |   |   |   |--- feature_1 <= 1.05
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  1.05
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  57.50
# |   |   |   |   |--- class: 1
# |--- feature_1 >  1.35
# |   |--- feature_1 <= 3.05
# |   |   |--- class: 0
# |   |--- feature_1 >  3.05
# |   |   |--- class: 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 13 columns):
# age         19 non-null int64
# sex         19 non-null int64
# cp          19 non-null int64
# trestbps    19 non-null int64
# fbs         19 non-null int64
# restecg     19 non-null int64
# thalach     19 non-null int64
# exang       19 non-null int64
# oldpeak     19 non-null float64
# slope       19 non-null int64
# ca          19 non-null int64
# thal        19 non-null int64
# target      19 non-null int64
# dtypes: float64(1), int64(12)
# memory usage: 2.0 KB
