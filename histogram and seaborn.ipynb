# %%
# import pandas for dataframes
import pandas as pd
#import numpy for numrical python
import numpy as np
# import matplotlib for visualization
import matplotlib.pyplot as plt

# display the plot in the same jupyter notebook
# %matplotlib inline

# import seaborn for easy visualization
import seaborn as sns

# %%
df=pd.read_csv('real_estate_data.csv')
df.head(3)
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
# 2    279900     1      1   615        1963         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
# 2  Apartment / Condo / Townhouse    Wood Siding                  NaN
#
#    basement  ...  beauty_spas  active_life  median_age  married  college_grad  \
# 0       NaN  ...           47           58        33.0     65.0          84.0
# 1       1.0  ...           26           14        39.0     73.0          69.0
# 2       NaN  ...           74           62        28.0     15.0          86.0
#
#    property_tax  insurance  median_school  num_schools  tx_year
# 0         234.0       81.0            9.0          3.0     2013
# ...

# %%
# we can hist() for histogram

df.hist(figsize=(15,15))
plt.show()

# %%
for i in df:
    df.hist(column=i, bins=25, grid=False, figsize=(8,10), layout=(3,1), sharex=True, color='#008000', zorder=2, rwidth=0.9)


  
    plt.show()

# %%
# for seaborn we use sns.countplot

sns.countplot(y='property_type',data=df)

# %%
#for i in df.dtypes(df.dtypes=='objest'):
    #sns.countplot(y=i,data=df)
for feature in df.dtypes[df.dtypes=='object'].index:
    sns.countplot(y = feature, data = df)
    plt.show()

# %% [markdown]
# TX_PRICE--
# Most of the tx_price ranges between 200000 to 500000
# there is no tx lower lthen 200000 and higher than 800000
#
# BEDS--
# most of the properties have 3 or 4 bedrooms(almost 2/3)
# some properties contain as low as 1 bedroom(0.05%)
# maximum 5 bedrooms are present in any property
#
# BATHS--
# most of the properties have 2 or 3 bathroom(almost 2/3)
# some properties contain as low as 1 bathroom(0.1%)
# maximum 6 bathrooms are present in any property
#
# SQFT---
# Maximum houses range between 1000 to 3000
# Properties start from 500 sqft toal floor area
# Properties end at 8450 sqft toal floor area
#
# YEAR BUIT---
# Most property ware built in between 1960 to 2010
# All properties ware built in between 1880 to 2015

# %%
# for accessing all statistic function we import statistics
import statistics


num=[1,45,34,3,100,50]
rr =(statistics.variance(num))
ss=(statistics.stdev(num))
print('variance of num is',rr)
print('Daviation of num is',ss)
# Out:
# variance of num is 1328.5666666666666
# Daviation of num is 36.449508455762015

# %%
# Importing Statistics module 
import statistics 
  
# Creating a sample of data 
sample = [2.74, 1.23, 2.63, 2.22, 3, 1.98] 
  
# Prints variance of the sample set 
  
# Function will automatically calulate 
# it's mean and set it as xbar 
print("Variance of sample set is % s" 
      %(statistics.variance(sample)))
# Out:
# Variance of sample set is 0.40924

# %%
def median(a, l, r): 
    n = r - l + 1
    n = (n + 1) // 2 - 1
    return n + l 
  
# Function to calculate IQR 
def IQR(a, n): 
  
    a.sort() 
  
    # Index of median of entire data 
    mid_index = median(a, 0, n) 
  
    # Median of first half 
    Q1 = a[median(a, 0, mid_index)] 
  
    # Median of second half 
    Q3 = a[median(a, mid_index + 1, n)] 
  
    # IQR calculation 
    return (Q3 - Q1) 
  
# Driver Function 
if __name__=='__main__': 
    a = [1, 19, 7, 6, 5, 9, 12, 27, 18, 2, 15] 
    n = len(a) 
    print(IQR(a, n))
# Out:
# 13

# %%
# we are using df.corr() for correlation
plt.figure(figsize=(9,5))
correlations=df.corr()
sns.heatmap(correlations)
plt.show()

# %%
# Seaborn's Heatmap

plt.figure(figsize=(10,5))

# change the color scheme

sns.set_style("whitegrid")

# Ploting heat map of correlations

sns.heatmap(correlations*100,annot=True,fmt='.0f')
plt.show()

# %%
# Generate a mask to upper triangel

mask = np.zeros_like(correlations,dtype=np.bool)
mask[np.triu_indices_from(mask)]= True

# %%
# Seaborn's Heatmap

plt.figure(figsize=(9,5))

# change the color scheme

sns.set_style("whitegrid")

# Ploting heat map of correlations

sns.heatmap(correlations*100,annot=True,fmt='.0f',mask = mask)
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',100)

# %%
df=pd.read_csv('real_estate_data.csv')
df
# Out:
#       tx_price  beds  baths  sqft  year_built  lot_size  \
# 0       295850     1      1   584        2013         0
# 1       216500     1      1   612        1965         0
# 2       279900     1      1   615        1963         0
# 3       379900     1      1   618        2000     33541
# 4       340000     1      1   634        1992         0
# 5       265000     1      1   641        1947         0
# 6       240000     1      1   642        1944         0
# 7       388100     1      1   650        2000     33541
# 8       240000     1      1   660        1983         0
# 9       250000     1      1   664        1965         0
# 10      335000     1      1   669        2006         0
# 11      376750     1      1   673        2005     46609
# 12      210000     1      1   680        1963         0
# 13      289900     1      1   685        1960     48787
# 14      535000     1      1   687        2008         0
# 15      218000     1      1   689        1988         0
# ...

# %%
pd.set_option('display.max_columns',100)

# %%
df.head(2)
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
#
#    basement  restaurants  groceries  nightlife  cafes  shopping  \
# 0       NaN          107          9         30     19        89
# 1       1.0          105         15          6     13        87
#
#    arts_entertainment  beauty_spas  active_life  median_age  married  \
# 0                   6           47           58        33.0     65.0
# 1                   2           26           14        39.0     73.0
#
#    college_grad  property_tax  insurance  median_school  num_schools  tx_year
# 0          84.0         234.0       81.0            9.0          3.0     2013
# ...

# %%
#counting total rows
count=0
for i in df.index:
    count+=1
print(count)
# Out:
# 1883

# %%
# checking total columns
df.columns
# Out:
# Index(['tx_price', 'beds', 'baths', 'sqft', 'year_built', 'lot_size',
#        'property_type', 'exterior_walls', 'roof', 'basement', 'restaurants',
#        'groceries', 'nightlife', 'cafes', 'shopping', 'arts_entertainment',
#        'beauty_spas', 'active_life', 'median_age', 'married', 'college_grad',
#        'property_tax', 'insurance', 'median_school', 'num_schools', 'tx_year'],
#       dtype='object')

# %%
df.shape
# Out:
# (1883, 26)

# %%
df.dtypes
# Out:
# tx_price                int64
# beds                    int64
# baths                   int64
# sqft                    int64
# year_built              int64
# lot_size                int64
# property_type          object
# exterior_walls         object
# roof                   object
# basement              float64
# restaurants             int64
# groceries               int64
# nightlife               int64
# cafes                   int64
# shopping                int64
# arts_entertainment      int64
# beauty_spas             int64
# active_life             int64
# median_age            float64
# married               float64
# college_grad          float64
# property_tax          float64
# insurance             float64
# median_school         float64
# num_schools           float64
# tx_year                 int64
# dtype: object

# %%
for i in df.dtypes[df.dtypes=='object'].index:
    print(i)
# Out:
# property_type
# exterior_walls
# roof

# %%
df.describe()
# Out:
#             tx_price         beds        baths         sqft   year_built  \
# count    1883.000000  1883.000000  1883.000000  1883.000000  1883.000000
# mean   422839.807754     3.420605     2.579926  2329.398832  1982.963887
# std    151462.593276     1.068554     0.945576  1336.991858    20.295945
# min    200000.000000     1.000000     1.000000   500.000000  1880.000000
# 25%    300000.000000     3.000000     2.000000  1345.000000  1970.000000
# 50%    392000.000000     3.000000     3.000000  1907.000000  1986.000000
# 75%    525000.000000     4.000000     3.000000  3005.000000  2000.000000
# max    800000.000000     5.000000     6.000000  8450.000000  2015.000000
#
#            lot_size  basement  restaurants    groceries    nightlife  \
# count  1.883000e+03    1657.0  1883.000000  1883.000000  1883.000000
# mean   1.339262e+04       1.0    40.210303     4.505045     5.074881
# std    4.494930e+04       0.0    46.867012     4.491029     8.464668
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1883 entries, 0 to 1882
# Data columns (total 26 columns):
# tx_price              1883 non-null int64
# beds                  1883 non-null int64
# baths                 1883 non-null int64
# sqft                  1883 non-null int64
# year_built            1883 non-null int64
# lot_size              1883 non-null int64
# property_type         1883 non-null object
# exterior_walls        1660 non-null object
# roof                  1529 non-null object
# basement              1657 non-null float64
# restaurants           1883 non-null int64
# groceries             1883 non-null int64
# nightlife             1883 non-null int64
# cafes                 1883 non-null int64
# shopping              1883 non-null int64
# arts_entertainment    1883 non-null int64
# beauty_spas           1883 non-null int64
# active_life           1883 non-null int64
# median_age            1883 non-null float64
# ...

# %%
# identifying the unique
df.nunique()
# Out:
# tx_price               888
# beds                     5
# baths                    6
# sqft                  1307
# year_built              94
# lot_size               763
# property_type            2
# exterior_walls          16
# roof                    16
# basement                 1
# restaurants            177
# groceries               25
# nightlife               47
# cafes                   44
# shopping               194
# arts_entertainment      31
# beauty_spas            116
# active_life             81
# median_age              40
# married                 85
# college_grad            83
# property_tax           555
# insurance              251
# median_school           16
# num_schools              4
# tx_year                 24
# dtype: int64

# %%
# for histogram first import 
df.hist(figsize=(20,20))
# for removing the log file we use
plt.show()

# %%
df.tx_year.hist(bins=25, grid=False, figsize=(8,5),color='#008000', zorder=2, rwidth=0.9)
plt.show()

# %%
df.tx_price.hist(figsize=(10,5),rwidth=0.9,bins=25,grid=False)
plt.show()

# %%
# when you describe data frame on that time its does not showing cetegorical columns
(df.describe()).columns
# Out:
# Index(['tx_price', 'beds', 'baths', 'sqft', 'year_built', 'lot_size',
#        'basement', 'restaurants', 'groceries', 'nightlife', 'cafes',
#        'shopping', 'arts_entertainment', 'beauty_spas', 'active_life',
#        'median_age', 'married', 'college_grad', 'property_tax', 'insurance',
#        'median_school', 'num_schools', 'tx_year'],
#       dtype='object')

# %%
# hare all columns are showing 
df.columns
# Out:
# Index(['tx_price', 'beds', 'baths', 'sqft', 'year_built', 'lot_size',
#        'property_type', 'exterior_walls', 'roof', 'basement', 'restaurants',
#        'groceries', 'nightlife', 'cafes', 'shopping', 'arts_entertainment',
#        'beauty_spas', 'active_life', 'median_age', 'married', 'college_grad',
#        'property_tax', 'insurance', 'median_school', 'num_schools', 'tx_year'],
#       dtype='object')

# %%
# if we want to describe  categorical value 
df.describe(include=['object'])
# Out:
#         property_type exterior_walls                 roof
# count            1883           1660                 1529
# unique              2             16                   16
# top     Single-Family          Brick  Composition Shingle
# freq             1080            687                 1179

# %%
# bar plot for exterior_walls
sns.countplot(y='exterior_walls',data=df)
plt.show()

# %%
# plot bar graphs for all the cetegorical features
for i in df.dtypes[df.dtypes=='object'].index:
    sns.countplot(y=i,data=df)
    plt.show()

# %%
# segment tx_price by property_type and plot the distribution
sns.boxplot(x='tx_price',y='property_type',data=df,width=0.5)
plt.show()

# %%
# if you want to compare 2 cetegories of property types, across many feature
df.groupby('property_type').mean()
# Out:
#                                     tx_price      beds     baths         sqft  \
# property_type
# Apartment / Condo / Townhouse  366614.034869  2.601494  2.200498  1513.727273
# Single-Family                  464644.711111  4.029630  2.862037  2935.865741
#
#                                 year_built      lot_size  basement  \
# property_type
# Apartment / Condo / Townhouse  1988.936488   3944.239103       1.0
# Single-Family                  1978.523148  20417.666667       1.0
#
#                                restaurants  groceries  nightlife     cafes  \
# property_type
# Apartment / Condo / Townhouse    58.418431   5.919054   7.855542  8.037360
# Single-Family                    26.672222   3.453704   3.007407  3.308333
#
#                                 shopping  arts_entertainment  beauty_spas  \
# property_type
# Apartment / Condo / Townhouse  57.631382            4.840598    32.087173
# Single-Family                  28.289815            2.318519    16.970370
#
# ...

# %%
# for standerd deviation
df.groupby('property_type').std()
# Out:
#                                     tx_price      beds     baths         sqft  \
# property_type
# Apartment / Condo / Townhouse  121784.490486  0.810220  0.815009   556.286650
# Single-Family                  157758.739013  0.795639  0.937551  1422.871169
#
#                                year_built      lot_size  basement  \
# property_type
# Apartment / Condo / Townhouse   15.513640  44284.168767       0.0
# Single-Family                   22.210582  44165.529302       0.0
#
#                                restaurants  groceries  nightlife     cafes  \
# property_type
# Apartment / Condo / Townhouse    54.343594   4.645774  10.643816  9.077038
# Single-Family                    34.726416   4.067285   5.543822  5.325053
#
#                                 shopping  arts_entertainment  beauty_spas  \
# property_type
# Apartment / Condo / Townhouse  61.852299            5.234834    26.910443
# Single-Family                  42.292313            3.929691    22.872112
#
# ...

# %%
# calculate correlation between numerical features
correlation=df.corr()
print(correlation.shape)
print(correlation.dtypes)
correlation
# Out:
# (23, 23)
# tx_price              float64
# beds                  float64
# baths                 float64
# sqft                  float64
# year_built            float64
# lot_size              float64
# basement              float64
# restaurants           float64
# groceries             float64
# nightlife             float64
# cafes                 float64
# shopping              float64
# arts_entertainment    float64
# beauty_spas           float64
# active_life           float64
# median_age            float64
# married               float64
# college_grad          float64
# property_tax          float64
# insurance             float64
# median_school         float64
# num_schools           float64
# tx_year               float64
# dtype: object
#                     tx_price      beds     baths      sqft  year_built  \
# tx_price            1.000000  0.384046  0.389375  0.469573    0.033138
# beds                0.384046  1.000000  0.644572  0.691039   -0.011844
# ...

# %%
plt.figure(figsize=(10,10))
#seaborn heatmap
sns.heatmap(correlation)
plt.show()

# %%
# seaborns heatmap with numberical observation
plt.figure(figsize=(10,10))

sns.heatmap(correlation*100,annot=True,fmt='.0f')
plt.show()

# %%
#generate a mask to upper triangle
mask=np.zeros_like(correlation,dtype=np.bool)
mask[np.triu_indices_from(mask)]=True

# %%
plt.figure(figsize=(9,9))

# change the colour scheme
sns.set_style('whitegrid')

sns.heatmap(correlation*100,annot=True,fmt='.0f',mask=mask)
plt.show()

# %% [markdown]
# ### Data Cleaning

# %%
df.shape
# Out:
# (1883, 26)

# %%
ww=pd.read_csv(r'D:\python class arja mohan\Pandas CSV data file/ram.csv')
ww
# Out:
#    RITESH RITESH.1 Sharma RITESH.2 SHAURYA
# 0       3        3      4        2      51
# 1       4        4      4        3      52
# 2       5        5      4        7      53
# 3       6        6      4        8      54
# 4       7        7      4        0      55
# 5       8        8      4       22      56
# 6       9        9      4       23      57
# 7      10       10      4       24      58
# 8      11       11      4       25      59
# 9      12       12      4       26      60
# 10     13       13      4       27      61
# 11     14       14      4       28      62
# 12    Nan      Nan    Nan      Nan     Nan

# %%
ww.shape
# Out:
# (13, 5)

# %%
ww.drop_duplicates()
# Out:
#    RITESH RITESH.1 Sharma RITESH.2 SHAURYA
# 0       3        3      4        2      51
# 1       4        4      4        3      52
# 2       5        5      4        7      53
# 3       6        6      4        8      54
# 4       7        7      4        0      55
# 5       8        8      4       22      56
# 6       9        9      4       23      57
# 7      10       10      4       24      58
# 8      11       11      4       25      59
# 9      12       12      4       26      60
# 10     13       13      4       27      61
# 11     14       14      4       28      62
# 12    Nan      Nan    Nan      Nan     Nan

# %%
ww.shape
# Out:
# (13, 5)

# %%
ww.Sharma.unique()
# Out:
# array(['4', 'Nan'], dtype=object)

# %%
ww.Sharma.value_counts()
# Out:
# 4      12
# Nan     1
# Name: Sharma, dtype: int64

# %%
ww.RITESH.value_counts()
# Out:
# 5      1
# 13     1
# 4      1
# 9      1
# 11     1
# 14     1
# 12     1
# 8      1
# 6      1
# 7      1
# Nan    1
# 10     1
# 3      1
# Name: RITESH, dtype: int64

# %%
ww['Sujjet']=range(13)

# %%
ww
# Out:
#    RITESH RITESH.1 Sharma RITESH.2 SHAURYA  Sujjet
# 0       3        3      4        2      51       0
# 1       4        4      4        3      52       1
# 2       5        5      4        7      53       2
# 3       6        6      4        8      54       3
# 4       7        7      4        0      55       4
# 5       8        8      4       22      56       5
# 6       9        9      4       23      57       6
# 7      10       10      4       24      58       7
# 8      11       11      4       25      59       8
# 9      12       12      4       26      60       9
# 10     13       13      4       27      61      10
# 11     14       14      4       28      62      11
# 12    Nan      Nan    Nan      Nan     Nan      12

# %%
ww.to_csv('ram.csv')

# %%
ww
# Out:
#    RITESH RITESH.1 Sharma RITESH.2 SHAURYA  Sujjet
# 0       3        3      4        2      51       0
# 1       4        4      4        3      52       1
# 2       5        5      4        7      53       2
# 3       6        6      4        8      54       3
# 4       7        7      4        0      55       4
# 5       8        8      4       22      56       5
# 6       9        9      4       23      57       6
# 7      10       10      4       24      58       7
# 8      11       11      4       25      59       8
# 9      12       12      4       26      60       9
# 10     13       13      4       27      61      10
# 11     14       14      4       28      62      11
# 12    Nan      Nan    Nan      Nan     Nan      12

# %%
for i in df.dtypes[df.dtypes=='object'].index:
    print(i)
# Out:
# property_type
# exterior_walls
# roof

# %%
plt.figure(figsize=(9,5))
sns.countplot(y='roof',data=df)
plt.show()

# %%
# in roof columns total unique features
df.roof.unique()
# Out:
# array([nan, 'Composition Shingle', 'Other', 'Gravel/Rock',
#        'Roll Composition', 'Asphalt', 'Slate', 'asphalt', 'Shake Shingle',
#        'Built-up', 'Asbestos', 'Metal', 'shake-shingle',
#        'Wood Shake/ Shingles', 'Composition', 'composition',
#        'asphalt,shake-shingle'], dtype=object)

# %%
# Duplicates values

# 1. asphalt------Asphalt
# 2. shake-shingle-----Shake shingle
# 3. asphalt,shake-shingle------Shake shingle
# 4. composition ------ Composition

# %%
# Replace the class asphalt with Asphalt
df.roof.replace('asphalt','Asphalt',inplace=True)

# %%
df.roof.unique()
df.roof.nunique()
# Out:
# 14

# %%
# Replace 'shake-shingle' and 'asphalt,shake-shingle' with Shake shingle
df.roof.replace(['shake-shingle' ,'asphalt,shake-shingle'],'Shake shingle',inplace=True)

# %%
df.roof.unique()
# Out:
# array([nan, 'Composition Shingle', 'Other', 'Gravel/Rock',
#        'Roll Composition', 'Asphalt', 'Slate', 'Shake Shingle',
#        'Built-up', 'Asbestos', 'Metal', 'Shake shingle',
#        'Wood Shake/ Shingles', 'Composition', 'composition'], dtype=object)

# %%
# Replace composition with Composition
df.roof.replace('composition','Composition',inplace=True)

# %%
df.roof.unique()
# Out:
# array([nan, 'Composition Shingle', 'Other', 'Gravel/Rock',
#        'Roll Composition', 'Asphalt', 'Slate', 'Shake Shingle',
#        'Built-up', 'Asbestos', 'Metal', 'Shake shingle',
#        'Wood Shake/ Shingles', 'Composition'], dtype=object)

# %%
sns.countplot(y='roof',data=df)

# %%
# removing duplicate values from exterior_wall
df.exterior_walls.unique()
# Out:
# array(['Wood Siding', 'Brick', 'Concrete Block', 'Wood',
#        'Siding (Alum/Vinyl)', 'Stucco', 'Concrete', 'Block', nan, 'Metal',
#        'Wood Shingle', 'Masonry', 'Brick veneer', 'Other', 'Combination',
#        'Asbestos shingle', 'Rock, Stone'], dtype=object)

# %%
# Replacing values
# replacing 'concrete','Block' with 'Concrete Block'
df.exterior_walls.replace(['concrete','Block'],'Concrete Block',inplace=True)

# replacing 'Rock','Stone' with Masonry
df.exterior_walls.replace('Rock, Stone' ,'Masonry',inplace=True)

# %%
df.exterior_walls.unique()
# Out:
# array(['Wood Siding', 'Brick', 'Concrete Block', 'Wood',
#        'Siding (Alum/Vinyl)', 'Stucco', 'Concrete', nan, 'Metal',
#        'Wood Shingle', 'Masonry', 'Brick veneer', 'Other', 'Combination',
#        'Asbestos shingle'], dtype=object)

# %%
sns.countplot(y='exterior_walls',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['tx_price', 'beds', 'baths', 'sqft', 'year_built', 'lot_size',
#        'property_type', 'exterior_walls', 'roof', 'basement', 'restaurants',
#        'groceries', 'nightlife', 'cafes', 'shopping', 'arts_entertainment',
#        'beauty_spas', 'active_life', 'median_age', 'married', 'college_grad',
#        'property_tax', 'insurance', 'median_school', 'num_schools', 'tx_year'],
#       dtype='object')

# %%
sns.boxplot(df.tx_price)

# %%
df.head(1)
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
#
#                    property_type exterior_walls roof  basement  ...  \
# 0  Apartment / Condo / Townhouse    Wood Siding  NaN       NaN  ...
#
#    beauty_spas  active_life  median_age  married  college_grad  property_tax  \
# 0           47           58        33.0     65.0          84.0         234.0
#
#    insurance  median_school  num_schools  tx_year
# 0       81.0            9.0          3.0     2013
#
# [1 rows x 26 columns]

# %%
sns.violinplot(df.beds)
plt.show()

# %%
df.columns
# Out:
# Index(['tx_price', 'beds', 'baths', 'sqft', 'year_built', 'lot_size',
#        'property_type', 'exterior_walls', 'roof', 'basement', 'restaurants',
#        'groceries', 'nightlife', 'cafes', 'shopping', 'arts_entertainment',
#        'beauty_spas', 'active_life', 'median_age', 'married', 'college_grad',
#        'property_tax', 'insurance', 'median_school', 'num_schools', 'tx_year'],
#       dtype='object')

# %%
sns.violinplot(df.beds)
plt.show()

# %%
ee=pd.DataFrame({'one':[1,2,3,4,5,1],'two':[1,2,3,4,5,6]})

# %%
sns.countplot(ee.data=ee)
# Out:
#   File "<ipython-input-40-284ed4b1493f>", line 1
#     sns.countplot(ee.data=ee)
#                  ^
# SyntaxError: keyword can't be an expression

# %%
from itertools import combinations

# %%
ww=combinations(ee.one,ee.two)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-cf5a34ab8448> in <module>
# ----> 1 ww=combinations(ee.one,ee.two)
#
# TypeError: 'Series' object cannot be interpreted as an integer

# %%
for i in ee.one:
    for a in ee.two:
        print(i*a)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 2
# 4
# 6
# 8
# 10
# 12
# 3
# 6
# 9
# 12
# 15
# 18
# 4
# 8
# 12
# 16
# 20
# 24
# 5
# 10
# 15
# 20
# 25
# 30
# 1
# 2
# 3
# 4
# 5
# 6
