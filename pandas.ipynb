# %% [markdown]
# # Pandas
# Pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %%
# importing pandas into our environment

import pandas as pd
import numpy as np

# %% [markdown]
# Pandas will provide special data type -> Data Frames(pandas.core.frame.DataFame)

# %%
# simple data frame creation

ex_df = pd.DataFrame({'column_1': [1,2,3,4,5,6],'column_2': ['a','b','c','d','e','f']})

# %%
ex_df
# Out:
#    column_1 column_2
# 0         1        a
# 1         2        b
# 2         3        c
# 3         4        d
# 4         5        e
# 5         6        f

# %%
new = pd.DataFrame(np.arange(0,20).reshape(5,4),index = ['one','two','three','four','five'],columns = ['col1','col2','col3','col4'])

# %%
new
# Out:
#        col1  col2  col3  col4
# one       0     1     2     3
# two       4     5     6     7
# three     8     9    10    11
# four     12    13    14    15
# five     16    17    18    19

# %% [markdown]
# ### any one column and row is a series

# %%
new.loc['one']
# Out:
# col1    0
# col2    1
# col3    2
# col4    3
# Name: one, dtype: int32

# %%
type(new.loc['one'])
# Out:
# pandas.core.series.Series

# %%
new['col1']
# Out:
# one       0
# two       4
# three     8
# four     12
# five     16
# Name: col1, dtype: int32

# %%
type(new['col1'])
# Out:
# pandas.core.series.Series

# %%
new.iloc[:] #--right side is a row and left side is a column
# Out:
#        col1  col2  col3  col4
# one       0     1     2     3
# two       4     5     6     7
# three     8     9    10    11
# four     12    13    14    15
# five     16    17    18    19

# %%
new.iloc[0:2,:] #---hare it will show only 0 and 1 index rows
# Out:
#      col1  col2  col3  col4
# one     0     1     2     3
# two     4     5     6     7

# %%
new.iloc[:1,:] #--hare it will show only 0 and 1 index columns
# Out:
#      col1  col2  col3  col4
# one     0     1     2     3

# %%
type(new.iloc[:1,:0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### convert dataframe into array

# %%
new1= new.iloc[:,1:].values

# %%
new1
# Out:
# array([[ 1,  2,  3],
#        [ 5,  6,  7],
#        [ 9, 10, 11],
#        [13, 14, 15],
#        [17, 18, 19]])

# %%
# creation of sample table 
stu_df = pd.DataFrame({'Details': ['Name', 'Email_id', 'Cell_Number', 'Current_Designation', 'Domain', 'Location'],
                       'Chandrika':['Chandrika', 'chandrika3772@gmail.com', '8977245972', 'Student', 'Information Systems and Business Analytics', 'United States'],
'JOY':['JOY CHOUDHURY', 'joy2kcentury@gmail.com','+91 9853566499', 'Engineer', 'Industrial Automation', 'Odisha'],'Anilsharma':['anil', 'anilsharmam@hotmail.com', '9010464464', 'Finance consultant', 'Project Management-finance', 'Hyderabad'],'RITESH':['RITESH','ritish.tiwiari@gmail.com',9040398286,'Engineer','KEPCOKPS','Odisha']})

# %%
stu_df

# %%
# 1. how you will access a specific column?
# 2. How you will access a required columns more than one?
# 3. How you will access a specific row from the data frame?
# 4. How you will access group of columns in the dataFrame?

#  Iris flowers(need to do some research on flower anotomy)

# %%
stu_df[['RITESH']]

# %%
stu_df[["RITESH", "JOY"]]

# %%
stu_df.iloc[[1,3]]

# %%
df=pd.read_csv(r'C:\Users\RITESH TIWARI\Desktop\fdf/iris.csv')

# %%
df

# %%
#df.head()#/with and with out arguments
#df.tail()#/with and with out arguments
df.describe() # what information it is giving 

# 1. need to add one more column in the data whicu is the result of any of your choice?
# 2. you need to identify the size of the data?
# 3. You need to identify the data types of all columns?
# 4. how many null and not null values in each and every column?
# 5. What is the minimum and maximum values in each and every row?
# 6. how many unique elements in each and every row?
# 7. how to update the column names?
# 8. how to find duplicates in the data?

# %%
#adding new column in pandas
df['Total']=" "
df

# %%
# size od the Data
df.size

# %%
df.shape

# %%
df.ndim

# %%
# Data types of all columns
df.dtypes

# %%
#Count all Null in a DataFrame (both columns & Rows)
df.isnull().sum().sum()

# %%
#Count all Null at each columns a DataFrame
df.isnull().sum()

# %%
# count of null at each row:
for i in range(len(df)):
    print(f'null of row {i} :{df.iloc[i].isnull().sum()}')

# %%
#maximum values of each and every columns
df.max()

# %%
#minimum values of each and every columns
df.min()

# %%
##maximum values of each and every rows.
df.max(axis=1)

# %%
#minimum values of each and every columns
df.min(axis=1)

# %%
#how many unique elements in each and every row?
df.drop_duplicates()

# %%
how many unique elements in each and every row?

# %%
print(df.duplicated())

# %%
#how to update the column names?
print(df.columns)
df.rename(columns={'Total':'sum'})

# %%
#how to find duplicates in the data

# %%
# Define a dictionary containing Students data 
data = {'Name': ['Jai', 'jai','Princi', 'Gaurav', 'Anuj'], 
        'Height': [5.1, 5.1,5.6, 5.1, 5.2], 
        'Qualification': ['Msc','Msc', 'MA', 'Msc', 'Msc']} 
  
# Convert the dictionary into DataFrame 
dd = pd.DataFrame(data) 
  
# Declare a list that is to be converted into a column 

  
# Using 'Address' as the column name 
# and equating it to the list 
dd['Address'] =" "  
  
# Observe the result 
dd

# %%
dd.drop_duplicates()

# %%
ram=pd.DataFrame({'Ditals':['name','address','school','age'],'Ritesh':['Ritesh Tiwari','Brajrajnagar','LLPRUVM',36]})

# %%
ram['columns']=" "
ram

# %%
ram

# %%
#how to change columns name
lable=['DITALS','RITESH','COLUMNS']
ram.columns=lable
ram

# %%
ram[['Ritesh']]

# %%
ram.iloc[[1]]

# %%
ram.iloc[[2]]

# %%
ram.size

# %%
ram.max()

# %%
ram.min()

# %%
ram.head()

# %%
ram.tail()

# %%
ram.describe()

# %%
ram['total']=" "

# %%
ram

# %%
ram

# %%
# Build a list of labels: list_labels
list_labels = [['year','artist','song','chart weeks']]

# Assign the list of labels to the columns attribute: df.columns
df=pd.DataFrame(list_labels)
df.columns = list_labels
df

# %%
import pandas as pd

# %%
information=['name','address','school','dist']
Ritesh=['RItesh','BRJN','LLPRUVM','JSG']
rr=pd.DataFrame({'Information':information,'Ditails':Ritesh})
rr

# %%
rr[[Ditails]]

# %%
#making new colmn and import data
rr['sum']=range(4)
rr

# %%
#change index value

tt=pd.DataFrame({"Information":['rr'],"Ditails":['ree'],'sum':4})
tt
rr=pd.concat([rr,tt],ignore_index=True)
rrr=rr.rename(index={0:'zero',1:'one'})
rrr

# %%
xx=pd.concat([rr,tt])
xx

# %%
#make new colmn and import data
rr['mark']=[100,200,100,300]
rr

# %%
#print(rr.iloc[[0]])
print(rr.iloc[[1,2,3]])

# %%
rr['total']=' '
rr

# %%
rr

# %%
rr['total']=' '
rr

# %%
rr['total']=range(1,9,2)
rr

# %%
rr

# %%
rr

# %%
rr

# %%
rrr

# %%
dex=['a','b','c','d','e','f','g','h','i','j']
rrr.index=(dex)
rrr

# %%
df=pd.read_csv(r'C:\Users\RITESH TIWARI\Desktop\fdf/iris.csv')
df

# %%
df.head(5)

# %%
df.tail(8)

# %%
df[['sepal_width']]

# %%
df.iloc[[0,1]]

# %%
df.info()

# %%
# Loading the data
import numpy as np
import pandas as pd

read=pd.read_csv('real_estate_data.csv')

# %%
read
# Out:
#       tx_price  beds  baths  sqft  year_built  lot_size  \
# 0       295850     1      1   584        2013         0
# 1       216500     1      1   612        1965         0
# 2       279900     1      1   615        1963         0
# 3       379900     1      1   618        2000     33541
# 4       340000     1      1   634        1992         0
# 5       265000     1      1   641        1947         0
# 6       240000     1      1   642        1944         0
# 7       388100     1      1   650        2000     33541
# 8       240000     1      1   660        1983         0
# 9       250000     1      1   664        1965         0
# 10      335000     1      1   669        2006         0
# 11      376750     1      1   673        2005     46609
# 12      210000     1      1   680        1963         0
# 13      289900     1      1   685        1960     48787
# 14      535000     1      1   687        2008         0
# 15      218000     1      1   689        1988         0
# ...

# %%
# show all of columns name on pandas dataframe

pd.set_option('display.max_columns',30)

# %%
read.head()

# %%
read.describe()

# %%
read.info()

# %%
read.head()
