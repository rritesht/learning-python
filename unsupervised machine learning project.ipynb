# %%
import pandas as pd
import numpy as np
import matplotlib 
from matplotlib import pyplot
import seaborn as sns
pd.set_option('')

# %%
df=pd.read_csv('int_online_tx.csv')

# %%
df.head()
# Out:
#    InvoiceNo StockCode                      Description  Quantity  \
# 0     536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1     536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2     536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3     536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4     536370     21883                 STARS GIFT TAPE         24
#
#     InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/10 8:45       3.75     12583.0  France
# 1  12/1/10 8:45       3.75     12583.0  France
# 2  12/1/10 8:45       3.75     12583.0  France
# 3  12/1/10 8:45       0.85     12583.0  France
# 4  12/1/10 8:45       0.65     12583.0  France

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35116 entries, 0 to 35115
# Data columns (total 8 columns):
# InvoiceNo      35116 non-null int64
# StockCode      35116 non-null object
# Description    35116 non-null object
# Quantity       35116 non-null int64
# InvoiceDate    35116 non-null object
# UnitPrice      35116 non-null float64
# CustomerID     33698 non-null float64
# Country        35116 non-null object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.1+ MB

# %%
4 number of object colums 
2 numbers of float colums
2 int columns
2.1 memory its teken
total 8 columns
# Out:
# array([[536370, '22728', 'ALARM CLOCK BAKELIKE PINK', ..., 3.75, 12583.0,
#         'France'],
#        [536370, '22727', 'ALARM CLOCK BAKELIKE RED ', ..., 3.75, 12583.0,
#         'France'],
#        [536370, '22726', 'ALARM CLOCK BAKELIKE GREEN', ..., 3.75,
#         12583.0, 'France'],
#        ...,
#        [581587, '23254', 'CHILDRENS CUTLERY DOLLY GIRL ', ..., 4.15,
#         12680.0, 'France'],
#        [581587, '23255', 'CHILDRENS CUTLERY CIRCUS PARADE', ..., 4.15,
#         12680.0, 'France'],
#        [581587, '22138', 'BAKING SET 9 PIECE RETROSPOT ', ..., 4.95,
#         12680.0, 'France']], dtype=object)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 1         536370     22727            ALARM CLOCK BAKELIKE RED         24
# 2         536370     22726           ALARM CLOCK BAKELIKE GREEN        12
# 3         536370     21724      PANDA AND BUNNIES STICKER SHEET        12
# 4         536370     21883                     STARS GIFT TAPE         24
# 5         536370     10002          INFLATABLE POLITICAL GLOBE         48
# 6         536370     21791   VINTAGE HEADS AND TAILS CARD GAME         24
# 7         536370     21035      SET/2 RED RETROSPOT TEA TOWELS         18
# 8         536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND         24
# 9         536370     22629                  SPACEBOY LUNCH BOX         24
# 10        536370     22659              LUNCH BOX I LOVE LONDON        24
# 11        536370     22631             CIRCUS PARADE LUNCH BOX         24
# ...

# %%
ram=df[['StockCode','Description']]

# %%
ram.head()
# Out:
#   StockCode                      Description
# 0     22728        ALARM CLOCK BAKELIKE PINK
# 1     22727        ALARM CLOCK BAKELIKE RED
# 2     22726       ALARM CLOCK BAKELIKE GREEN
# 3     21724  PANDA AND BUNNIES STICKER SHEET
# 4     21883                 STARS GIFT TAPE

# %%
glist=df.Description
x=set(glist)
r=list(x)
len(r)
# Out:
# 2669

# %%
sns.lmplot(y='StockCode',x='Description',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1163         try:
# -> 1164             x = float(x)
#    1165         except Exception:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1166             try:
# -> 1167                 x = complex(x)
#    1168             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
c=[1,2,3,4,5]
d=['r','r','g','f','h']

# %%
ss=pd.DataFrame({'one':c,'two':d})

# %%
ss
# Out:
#    one two
# 0    1   r
# 1    2   r
# 2    3   g
# 3    4   f
# 4    5   h

# %%
ss.one.nunique()
# Out:
# 5

# %%
ss.two.nunique()
# Out:
# 4

# %%
ss.one,ss.two
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  4    5
#  Name: one, dtype: int64, 0    r
#  1    r
#  2    g
#  3    f
#  4    h
#  Name: two, dtype: object)

# %%
for i in ss.one:
    if i
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('one', 'two')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-219f14115dea> in <module>
# ----> 1 for i in ss['one','two']:
# ...
